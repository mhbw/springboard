# %% [markdown]
# # Project: Capstone Project 1: Data Wrangling
#
# The following are the code and description of the processes I used to collect, unify, and clean my data for the Springboard Capstone 1.
#
# All data was collected from [Natural Stat Trick](https://www.naturalstattrick.com/) an invaluable resource currated by Micah McCurdy, who compiles all kinds of data from the Nation Hockey League.
#
# The only preprocessing I did was to edit some of the header rows in the csv, and added a year column, in order to have that preserved.
#
# Naming conventions follow thusly:
#
# Year: refers to the year the season completed
# PK: means a penalty kill unit
# PP: means powerplay
# S: means 5-on-5 or standard play
# Counts: are an individual occurance
# Rates: are something over 60 minutes of time, the length of a standard game
#
# How to use this information: this means 'Player Season Totals - Natural Stat Trick-2015SOIRates.csv' is the Rate of recorded items during the 2014-2015 NHL regular season. 'Player Season Totals - Natural Stat Trick-2017PKindCounts.csv' would be the Count of items during the Penalty Kill for each individual player.
#
# I'll describe the remainder of my work as I go.

# %%
## import working modules
import pandas as pd
import numpy as np
import glob
import os
import unicodedata
from datetime import datetime
from functools import reduce

# %% [markdown]
# ### Structuring the Import
#
# I ran into a few issues starting out here. One that I had a number of files split out across the table given how I downloaded them, then the challenge of having some values that matter to the name space. I soved this buy iterating through all the csvs in the file, and saving the names into a separate list and then zipping them back together.

# %%
## loop through all the csvs, import them into a dictionary with edicted names
## first read all the csvs as raw files
## important note here, the output files save na values as "-", so those have to be dealt with. 
## you could do it later, but here I'm adding them in

df = [pd.read_csv(f,na_values = '-') for f in glob.glob('*.csv')]

## pull in the names and clean them
names = glob.glob('*.csv')
for i in range(len(names)):
    names[i]= names[i].replace("-","").replace("Natural Stat Trick","").replace(".csv","").replace(" ","")

## zip together for clean mapping and create dictionary
player_data = list(zip(names, df))
player_data_dict = dict(player_data)

# %% [markdown]
# ### The Sebastian Aho Problem
#
# I set the key as Player-Value-Team to solve for what I call the 'Sebastian Aho' problem, which is that there are two Sebastian Ahos that play in the league. This is a pretty standard problem in most large data sets, having name be unreliable, but here we lack another item to generate a unique index or primary key so this is what we're using. Also, it gives me the excuse to post [the Sebastian Aho trailer](https://www.youtube.com/watch?v=5dZo-866LP4) (which is very clever, go watch it, it's only a minute long).

# %%
## set index for joining
for key, value in player_data_dict.items():
    value.set_index(['Player','Year','Team'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-59f8aa4181ae> in <module>
#       1 ## set index for joining
#       2 for key, value in player_data_dict.items():
# ----> 3     value.set_index(['Player','Year','Team'], inplace=True)
#       4
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Player'

# %%
## this is generally just a gut check to see what's made it in clean and reference to find 
## the various frames later
player_data_dict.keys()
# Out:
# dict_keys(['PlayerSeasonTotals2014PKIndCounts', 'PlayerSeasonTotals2014PKOIRates', 'PlayerSeasonTotals2014PPindCounts', 'PlayerSeasonTotals2014PPOIRates', 'PlayerSeasonTotals2014SIndCounts', 'PlayerSeasonTotals2014SOIRates', 'PlayerSeasonTotals2015PKIndCounts', 'PlayerSeasonTotals2015PKOIRates', 'PlayerSeasonTotals2015PPIndCounts', 'PlayerSeasonTotals2015PPOIRates', 'PlayerSeasonTotals2015SIndCounts', 'PlayerSeasonTotals2015SOIRates', 'PlayerSeasonTotals2016PKindCounts', 'PlayerSeasonTotals2016PKOIRates', 'PlayerSeasonTotals2016PPindCounts', 'PlayerSeasonTotals2016PPOIRates', 'PlayerSeasonTotals2016SIndCounts', 'PlayerSeasonTotals2016SOIRates', 'PlayerSeasonTotals2017PKindCounts', 'PlayerSeasonTotals2017PKOIRates', 'PlayerSeasonTotals2017PPindCounts', 'PlayerSeasonTotals2017PPOIRates', 'PlayerSeasonTotals2017SIndCounts', 'PlayerSeasonTotals2017SOIRates', 'PlayerSeasonTotals2018PKindCounts', 'PlayerSeasonTotals2018PKOIRates', 'PlayerSeasonTotals2018PPindCounts', 'PlayerSeasonTotals2018PPOIRates', 'PlayerSeasonTotals2018SIndCounts', 'PlayerSeasonTotals2018SOIRates', 'player_data_2018', 'Playerbios2014', 'Playerbios2015', 'Playerbios2016', 'Playerbios2017', 'Playerbios2018', 'Playerbios2019'])

# %%
## cleaning up column headers
## all those not recorded here I manually replaced " " with "_" and "%" with "Per" prior to saving
## if not for my meddling with the flat files you wouldn't have to do this, and arguably it's not 
## necissary here, but I prefer it to be more standardized
keys = player_data_dict.keys()
for i in keys:
    player_data_dict[i].columns = player_data_dict[i].columns.str.replace(r" ", "_")
    player_data_dict[i].columns = player_data_dict[i].columns.str.replace(r"%","Per")

# %% [markdown]
# ### Joining The Dictionaries
#
# In order to create a case where each player had a record for every season they played, I needed to concat the various dictionaries by year, then append them all together, which is the next few cells.
#
# Not shown here, I did a couple checks to insure that the tables didn't inflate such as len(player_data_2014) and len(player_data_dict['PlayerSeasonTotals2014SIndCounts']) to make sure that there wasn't inflation there. I found exactly one that did increase due to a name capitalization item that I manually fixed. In fact this is the most common problem I've found in hockey data, which is with players coming from multiple nationalities there are a lot of interpritations of how to spell a name (Ales Hemsky is frequently Alex Hemski for example) so joining across platforms gets very tricky.
#
# Finally, after some deliberation, I decided that I would not add suffixes to the values of the first table, Standard Independant counts, because otherwise the power play table would stand as the item of record as far as things like Position, Games Played, etc. The main problem here is Natural Stat Trick would record 0 games played if a player had not had a power play shift or the like, which created a number of NA values that shouldn't have been.
#
# This does cause an accounting issue that I'll get into later but for now it's fine.

# %%
player_data_2014 = pd.merge(player_data_dict['PlayerSeasonTotals2014SIndCounts'],player_data_dict['PlayerSeasonTotals2014PPindCounts'], left_index=True, right_index=True, suffixes=("",'_PPIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2014PKIndCounts'],left_index=True, right_index=True, suffixes=("",'_PkIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2014PKOIRates'],left_index=True, right_index=True, suffixes=("",'_PkIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2014PPOIRates'],left_index=True, right_index=True, suffixes=("",'_PPIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2014SOIRates'],left_index=True, right_index=True, suffixes=("",'_SIndR'), how='outer').merge(player_data_dict['Playerbios2014'],left_index=True, right_index=True, suffixes=("",'_Bios'), how='outer')
player_data_2015 = pd.merge(player_data_dict['PlayerSeasonTotals2015SIndCounts'],player_data_dict['PlayerSeasonTotals2015PPIndCounts'], left_index=True, right_index=True, suffixes=("",'_PPIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2015PKIndCounts'],left_index=True, right_index=True, suffixes=("",'_PkIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2015PKOIRates'],left_index=True, right_index=True, suffixes=("",'_PkIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2015PPOIRates'],left_index=True, right_index=True, suffixes=("",'_PPIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2015SOIRates'],left_index=True, right_index=True, suffixes=("",'_SIndR'), how='outer').merge(player_data_dict['Playerbios2015'],left_index=True, right_index=True, suffixes=("",'_Bios'), how='outer')
player_data_2016 = pd.merge(player_data_dict['PlayerSeasonTotals2016SIndCounts'],player_data_dict['PlayerSeasonTotals2016PPindCounts'], left_index=True, right_index=True, suffixes=("",'_PPIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2016PKindCounts'],left_index=True, right_index=True, suffixes=("",'_PkIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2016PKOIRates'],left_index=True, right_index=True, suffixes=("",'_PkIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2016PPOIRates'],left_index=True, right_index=True, suffixes=("",'_PPIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2016SOIRates'],left_index=True, right_index=True, suffixes=("",'_SIndR'), how='outer').merge(player_data_dict['Playerbios2016'],left_index=True, right_index=True, suffixes=("",'_Bios'), how='outer')
player_data_2017 = pd.merge(player_data_dict['PlayerSeasonTotals2017SIndCounts'],player_data_dict['PlayerSeasonTotals2017PPindCounts'], left_index=True, right_index=True, suffixes=("",'_PPIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2017PKindCounts'],left_index=True, right_index=True, suffixes=("",'_PkIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2017PKOIRates'],left_index=True, right_index=True, suffixes=("",'_PkIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2017PPOIRates'],left_index=True, right_index=True, suffixes=("",'_PPIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2017SOIRates'],left_index=True, right_index=True, suffixes=("",'_SIndR'), how='outer').merge(player_data_dict['Playerbios2017'],left_index=True, right_index=True, suffixes=("",'_Bios'), how='outer')
player_data_2018 = pd.merge(player_data_dict['PlayerSeasonTotals2018SIndCounts'],player_data_dict['PlayerSeasonTotals2018PPindCounts'], left_index=True, right_index=True, suffixes=("",'_PPIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2018PKindCounts'],left_index=True, right_index=True, suffixes=("",'_PkIndC'), how='outer').merge(player_data_dict['PlayerSeasonTotals2018PKOIRates'],left_index=True, right_index=True, suffixes=("",'_PkIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2018PPOIRates'],left_index=True, right_index=True, suffixes=("",'_PPIndR'), how='outer').merge(player_data_dict['PlayerSeasonTotals2018SOIRates'],left_index=True, right_index=True, suffixes=("",'_SIndR'), how='outer').merge(player_data_dict['Playerbios2018'],left_index=True, right_index=True, suffixes=("",'_Bios'), how='outer')

comb_player_data = pd.concat([player_data_2014, player_data_2015, player_data_2016, player_data_2017, player_data_2018])

# %%
## visual check here 
print(comb_player_data)
# Out:
#                                     Position  GP          TOI  Goals  \
# Player                Year Team
# Aaron Ness            2014 NYI             D  20   275.250000      1
# Aaron Palushaj        2014 CAR             R   2    17.516667      0
# Aaron Rome            2014 DAL             D  25   301.200000      0
# Aaron Volpatti        2014 WSH             L  41   300.183333      2
# Adam Almquist         2014 DET             D   2    31.516667      1
# Adam Burish           2014 S.J             R  15   125.383333      0
# Adam Cracknell        2014 STL             R  19   151.050000      0
# Adam Hall             2014 PHI             R  80   544.033333      2
# Adam Henrique         2014 N.J             C  77  1056.600000     15
# Adam Larsson          2014 N.J             D  26   426.583333      1
# Adam McQuaid          2014 BOS             D  30   425.933333      1
# Adam Pardy            2014 WPG             D  60   802.633333      0
# Adam Payerl           2014 PIT             C   2    18.300000      0
# Alec Martinez         2014 L.A             D  61   809.066667      8
# Aleksander Barkov     2014 FLA             C  54   772.033333      5
# Ales Hemsky           2014 EDM, OTT        R  75  1006.350000     11
# Alex Chiasson         2014 DAL             R  79   884.716667      7
# Alex Galchenyuk       2014 MTL             C  65   802.083333     10
# Alex Goligoski        2014 DAL             D  81  1498.566667      3
# Alex Grant            2014 ANA             D   2    24.000000      2
# Alex Khokhlachev      2014 BOS             C   1    14.733333      0
# Alex Killorn          2014 T.B             L  82  1206.400000     14
# Alex Ovechkin         2014 WSH             L  78  1204.216667     27
# Alex Petrovic         2014 FLA             D   7    81.616667      0
# Alex Pietrangelo      2014 STL             D  81  1552.650000      6
# Alex Tanguay          2014 COL             L  16   217.966667      3
# Alexander Edler       2014 VAN             D  63  1147.200000      3
# Alexander Semin       2014 CAR             R  65  1034.583333     15
# Alexander Steen       2014 STL             L  68  1022.100000     24
# Alexander Sulzer      2014 BUF             D  25   391.183333      0
# ...                                      ...  ..          ...    ...
# Vladimir Tarasenko    2018 STL             R  80  1242.433333     27
# Vladislav Kamenev     2018 COL             C   3    26.383333      0
# Vladislav Namestnikov 2018 NYR, T.B        C  81  1132.733333     13
# Wade Megan            2018 STL             C   1     6.600000      0
# Warren Foegele        2018 CAR             L   2    19.750000      2
# Wayne Simmonds        2018 PHI             R  75  1042.416667     12
# Will Butcher          2018 N.J             D  81  1081.850000      2
# Will O'Neill          2018 PHI             D   1     9.416667      0
# William Carrier       2018 VGK             L  37   322.050000      1
# William Karlsson      2018 VGK             C  82  1199.666667     31
# William Nylander      2018 TOR             C  82  1200.416667     14
# Xavier Ouellet        2018 DET             D  45   564.183333      0
# Yanni Gourde          2018 T.B             C  82  1084.000000     17
# Yannick Weber         2018 NSH             D  47   559.683333      2
# Yohann Auvitu         2018 EDM             D  33   431.716667      3
# Zac Dalpe             2018 CBJ             C  12    86.416667      0
# Zac Rinaldo           2018 ARI             C  53   556.883333      5
# Zach Aston-Reese      2018 PIT             C  16   160.550000      4
# Zach Bogosian         2018 BUF             D  18   310.066667      0
# Zach Hyman            2018 TOR             C  82  1191.116667     14
# Zach Parise           2018 MIN             L  42   588.166667     13
# Zach Redmond          2018 BUF             D   3    42.816667      0
# Zach Trotman          2018 PIT             D   3    35.066667      0
# Zach Werenski         2018 CBJ             D  77  1491.000000     13
# Zach Whitecloud       2018 VGK             D   1    16.700000      0
# Zack Kassian          2018 EDM             R  74   747.800000      7
# Zack Mitchell         2018 MIN             R  23   226.533333      2
# Zack Smith            2018 OTT             L  68   935.600000      5
# Zdeno Chara           2018 BOS             D  73  1374.516667      7
# Zemgus Girgensons     2018 BUF             C  71   851.216667      5
#
#                                      Total_Assists  First_Assists  \
# Player                Year Team
# Aaron Ness            2014 NYI                   2              0
# Aaron Palushaj        2014 CAR                   0              0
# Aaron Rome            2014 DAL                   1              1
# Aaron Volpatti        2014 WSH                   0              0
# Adam Almquist         2014 DET                   0              0
# Adam Burish           2014 S.J                   0              0
# Adam Cracknell        2014 STL                   2              1
# Adam Hall             2014 PHI                   5              3
# Adam Henrique         2014 N.J                  11              5
# Adam Larsson          2014 N.J                   2              2
# Adam McQuaid          2014 BOS                   5              2
# Adam Pardy            2014 WPG                   6              2
# Adam Payerl           2014 PIT                   0              0
# Alec Martinez         2014 L.A                   6              2
# Aleksander Barkov     2014 FLA                  13             10
# Ales Hemsky           2014 EDM, OTT             18             10
# Alex Chiasson         2014 DAL                  15              7
# Alex Galchenyuk       2014 MTL                  11              8
# Alex Goligoski        2014 DAL                  24             13
# Alex Grant            2014 ANA                   0              0
# Alex Khokhlachev      2014 BOS                   0              0
# Alex Killorn          2014 T.B                  19              7
# Alex Ovechkin         2014 WSH                  12              9
# Alex Petrovic         2014 FLA                   1              1
# Alex Pietrangelo      2014 STL                  26             15
# Alex Tanguay          2014 COL                   5              1
# Alexander Edler       2014 VAN                   7              1
# Alexander Semin       2014 CAR                  14             10
# Alexander Steen       2014 STL                  17              8
# Alexander Sulzer      2014 BUF                   0              0
# ...                                            ...            ...
# Vladimir Tarasenko    2018 STL                  23             12
# Vladislav Kamenev     2018 COL                   0              0
# Vladislav Namestnikov 2018 NYR, T.B             19              8
# Wade Megan            2018 STL                   0              0
# Warren Foegele        2018 CAR                   1              1
# Wayne Simmonds        2018 PHI                  16              8
# Will Butcher          2018 N.J                  19              8
# Will O'Neill          2018 PHI                   0              0
# William Carrier       2018 VGK                   2              1
# William Karlsson      2018 VGK                  26             10
# William Nylander      2018 TOR                  34             22
# Xavier Ouellet        2018 DET                   7              3
# Yanni Gourde          2018 T.B                  32             19
# Yannick Weber         2018 NSH                   3              3
# Yohann Auvitu         2018 EDM                   6              2
# Zac Dalpe             2018 CBJ                   0              0
# Zac Rinaldo           2018 ARI                   2              1
# Zach Aston-Reese      2018 PIT                   2              2
# Zach Bogosian         2018 BUF                   1              1
# Zach Hyman            2018 TOR                  24             17
# Zach Parise           2018 MIN                   8              4
# Zach Redmond          2018 BUF                   0              0
# Zach Trotman          2018 PIT                   0              0
# Zach Werenski         2018 CBJ                  14              8
# Zach Whitecloud       2018 VGK                   0              0
# Zack Kassian          2018 EDM                   9              4
# Zack Mitchell         2018 MIN                   2              2
# Zack Smith            2018 OTT                  10              4
# Zdeno Chara           2018 BOS                  16              7
# Zemgus Girgensons     2018 BUF                   8              4
#
#                                      Second_Assists  Total_Points     IPP  \
# Player                Year Team
# Aaron Ness            2014 NYI                    2             3  100.00
# Aaron Palushaj        2014 CAR                    0             0     NaN
# Aaron Rome            2014 DAL                    0             1   10.00
# Aaron Volpatti        2014 WSH                    0             2   50.00
# Adam Almquist         2014 DET                    0             1   50.00
# Adam Burish           2014 S.J                    0             0    0.00
# Adam Cracknell        2014 STL                    1             2   33.33
# Adam Hall             2014 PHI                    2             7   53.85
# Adam Henrique         2014 N.J                    6            26   65.00
# Adam Larsson          2014 N.J                    0             3   27.27
# Adam McQuaid          2014 BOS                    3             6   28.57
# Adam Pardy            2014 WPG                    4             6   20.00
# Adam Payerl           2014 PIT                    0             0     NaN
# Alec Martinez         2014 L.A                    4            14   38.89
# Aleksander Barkov     2014 FLA                    3            18   54.55
# Ales Hemsky           2014 EDM, OTT               8            29   67.44
# Alex Chiasson         2014 DAL                    8            22   64.71
# Alex Galchenyuk       2014 MTL                    3            21   70.00
# Alex Goligoski        2014 DAL                   11            27   38.57
# Alex Grant            2014 ANA                    0             2   66.67
# Alex Khokhlachev      2014 BOS                    0             0     NaN
# Alex Killorn          2014 T.B                   12            33   57.89
# Alex Ovechkin         2014 WSH                    3            39   88.64
# Alex Petrovic         2014 FLA                    0             1   14.29
# Alex Pietrangelo      2014 STL                   11            32   40.51
# Alex Tanguay          2014 COL                    4             8   57.14
# Alexander Edler       2014 VAN                    6            10   47.62
# Alexander Semin       2014 CAR                    4            29   60.42
# Alexander Steen       2014 STL                    9            41   73.21
# Alexander Sulzer      2014 BUF                    0             0    0.00
# ...                                             ...           ...     ...
# Vladimir Tarasenko    2018 STL                   11            50   68.49
# Vladislav Kamenev     2018 COL                    0             0     NaN
# Vladislav Namestnikov 2018 NYR, T.B              11            32   60.38
# Wade Megan            2018 STL                    0             0     NaN
# Warren Foegele        2018 CAR                    0             3  100.00
# Wayne Simmonds        2018 PHI                    8            28   66.67
# Will Butcher          2018 N.J                   11            21   41.18
# Will O'Neill          2018 PHI                    0             0     NaN
# William Carrier       2018 VGK                    1             3   37.50
# William Karlsson      2018 VGK                   16            57   70.37
# William Nylander      2018 TOR                   12            48   64.00
# Xavier Ouellet        2018 DET                    4             7   33.33
# Yanni Gourde          2018 T.B                   13            49   73.13
# Yannick Weber         2018 NSH                    0             5   33.33
# Yohann Auvitu         2018 EDM                    4             9   34.62
# Zac Dalpe             2018 CBJ                    0             0    0.00
# Zac Rinaldo           2018 ARI                    1             7   38.89
# Zach Aston-Reese      2018 PIT                    0             6   85.71
# Zach Bogosian         2018 BUF                    0             1   20.00
# Zach Hyman            2018 TOR                    7            38   54.29
# Zach Parise           2018 MIN                    4            21   70.00
# Zach Redmond          2018 BUF                    0             0    0.00
# Zach Trotman          2018 PIT                    0             0     NaN
# Zach Werenski         2018 CBJ                    6            27   36.99
# Zach Whitecloud       2018 VGK                    0             0    0.00
# Zack Kassian          2018 EDM                    5            16   72.73
# Zack Mitchell         2018 MIN                    0             4   57.14
# Zack Smith            2018 OTT                    6            15   60.00
# Zdeno Chara           2018 BOS                    9            23   31.51
# Zemgus Girgensons     2018 BUF                    4            13   56.52
#
#                                      Shots           ...            \
# Player                Year Team                      ...
# Aaron Ness            2014 NYI          23           ...
# Aaron Palushaj        2014 CAR           2           ...
# Aaron Rome            2014 DAL          15           ...
# Aaron Volpatti        2014 WSH          18           ...
# Adam Almquist         2014 DET           2           ...
# Adam Burish           2014 S.J           9           ...
# Adam Cracknell        2014 STL          16           ...
# Adam Hall             2014 PHI          49           ...
# Adam Henrique         2014 N.J          98           ...
# Adam Larsson          2014 N.J          20           ...
# Adam McQuaid          2014 BOS          25           ...
# Adam Pardy            2014 WPG          45           ...
# Adam Payerl           2014 PIT           4           ...
# Alec Martinez         2014 L.A          52           ...
# Aleksander Barkov     2014 FLA          74           ...
# Ales Hemsky           2014 EDM, OTT    125           ...
# Alex Chiasson         2014 DAL          85           ...
# Alex Galchenyuk       2014 MTL          87           ...
# Alex Goligoski        2014 DAL          91           ...
# Alex Grant            2014 ANA           2           ...
# Alex Khokhlachev      2014 BOS           2           ...
# Alex Killorn          2014 T.B         149           ...
# Alex Ovechkin         2014 WSH         247           ...
# Alex Petrovic         2014 FLA           4           ...
# Alex Pietrangelo      2014 STL         122           ...
# Alex Tanguay          2014 COL          19           ...
# Alexander Edler       2014 VAN         135           ...
# Alexander Semin       2014 CAR         158           ...
# Alexander Steen       2014 STL         144           ...
# Alexander Sulzer      2014 BUF          18           ...
# ...                                    ...           ...
# Vladimir Tarasenko    2018 STL         229           ...
# Vladislav Kamenev     2018 COL           1           ...
# Vladislav Namestnikov 2018 NYR, T.B    114           ...
# Wade Megan            2018 STL           1           ...
# Warren Foegele        2018 CAR           6           ...
# Wayne Simmonds        2018 PHI         113           ...
# Will Butcher          2018 N.J          52           ...
# Will O'Neill          2018 PHI           3           ...
# William Carrier       2018 VGK          52           ...
# William Karlsson      2018 VGK         139           ...
# William Nylander      2018 TOR         146           ...
# Xavier Ouellet        2018 DET          53           ...
# Yanni Gourde          2018 T.B         112           ...
# Yannick Weber         2018 NSH          40           ...
# Yohann Auvitu         2018 EDM          66           ...
# Zac Dalpe             2018 CBJ          16           ...
# Zac Rinaldo           2018 ARI          54           ...
# Zach Aston-Reese      2018 PIT          19           ...
# Zach Bogosian         2018 BUF          28           ...
# Zach Hyman            2018 TOR         139           ...
# Zach Parise           2018 MIN          92           ...
# Zach Redmond          2018 BUF           7           ...
# Zach Trotman          2018 PIT           3           ...
# Zach Werenski         2018 CBJ         171           ...
# Zach Whitecloud       2018 VGK           0           ...
# Zack Kassian          2018 EDM          80           ...
# Zack Mitchell         2018 MIN          16           ...
# Zack Smith            2018 OTT         107           ...
# Zdeno Chara           2018 BOS         130           ...
# Zemgus Girgensons     2018 BUF         100           ...
#
#                                      Birth_State/Province  Birth_Country  \
# Player                Year Team
# Aaron Ness            2014 NYI                         MN            USA
# Aaron Palushaj        2014 CAR                         MI            USA
# Aaron Rome            2014 DAL                         MB            CAN
# Aaron Volpatti        2014 WSH                         BC            CAN
# Adam Almquist         2014 DET                        NaN            SWE
# Adam Burish           2014 S.J                         WI            USA
# Adam Cracknell        2014 STL                         SK            CAN
# Adam Hall             2014 PHI                         MI            USA
# Adam Henrique         2014 N.J                         ON            CAN
# Adam Larsson          2014 N.J                        NaN            SWE
# Adam McQuaid          2014 BOS                         PE            CAN
# Adam Pardy            2014 WPG                         NL            CAN
# Adam Payerl           2014 PIT                         ON            CAN
# Alec Martinez         2014 L.A                         MI            USA
# Aleksander Barkov     2014 FLA                        NaN            FIN
# Ales Hemsky           2014 EDM, OTT                   NaN            CZE
# Alex Chiasson         2014 DAL                         QC            CAN
# Alex Galchenyuk       2014 MTL                         WI            USA
# Alex Goligoski        2014 DAL                         MN            USA
# Alex Grant            2014 ANA                         NS            CAN
# Alex Khokhlachev      2014 BOS                        NaN            RUS
# Alex Killorn          2014 T.B                         NS            CAN
# Alex Ovechkin         2014 WSH                        NaN            RUS
# Alex Petrovic         2014 FLA                         AB            CAN
# Alex Pietrangelo      2014 STL                         ON            CAN
# Alex Tanguay          2014 COL                         QC            CAN
# Alexander Edler       2014 VAN                        NaN            SWE
# Alexander Semin       2014 CAR                        NaN            RUS
# Alexander Steen       2014 STL                         MB            CAN
# Alexander Sulzer      2014 BUF                        NaN            DEU
# ...                                                   ...            ...
# Vladimir Tarasenko    2018 STL                        NaN            RUS
# Vladislav Kamenev     2018 COL                        NaN            RUS
# Vladislav Namestnikov 2018 NYR, T.B                   NaN            RUS
# Wade Megan            2018 STL                         NY            USA
# Warren Foegele        2018 CAR                         ON            CAN
# Wayne Simmonds        2018 PHI                         ON            CAN
# Will Butcher          2018 N.J                         WI            USA
# Will O'Neill          2018 PHI                         MA            USA
# William Carrier       2018 VGK                         QC            CAN
# William Karlsson      2018 VGK                        NaN            SWE
# William Nylander      2018 TOR                         AB            CAN
# Xavier Ouellet        2018 DET                        NaN            FRA
# Yanni Gourde          2018 T.B                         QC            CAN
# Yannick Weber         2018 NSH                        NaN            CHE
# Yohann Auvitu         2018 EDM                        NaN            FRA
# Zac Dalpe             2018 CBJ                         ON            CAN
# Zac Rinaldo           2018 ARI                         ON            CAN
# Zach Aston-Reese      2018 PIT                         NY            USA
# Zach Bogosian         2018 BUF                         NY            USA
# Zach Hyman            2018 TOR                         ON            CAN
# Zach Parise           2018 MIN                         MN            USA
# Zach Redmond          2018 BUF                         MI            USA
# Zach Trotman          2018 PIT                         IN            USA
# Zach Werenski         2018 CBJ                         MI            USA
# Zach Whitecloud       2018 VGK                         MB            CAN
# Zack Kassian          2018 EDM                         ON            CAN
# Zack Mitchell         2018 MIN                         ON            CAN
# Zack Smith            2018 OTT                         SK            CAN
# Zdeno Chara           2018 BOS                        NaN            SVK
# Zemgus Girgensons     2018 BUF                        NaN            LVA
#
#                                      Nationality  Height_(in)  Weight_(lbs)  \
# Player                Year Team
# Aaron Ness            2014 NYI               USA           70           184
# Aaron Palushaj        2014 CAR               USA           72           187
# Aaron Rome            2014 DAL               CAN           73           220
# Aaron Volpatti        2014 WSH               CAN           72           215
# Adam Almquist         2014 DET               SWE           71           174
# Adam Burish           2014 S.J               USA           73           195
# Adam Cracknell        2014 STL               CAN           74           209
# Adam Hall             2014 PHI               USA           74           212
# Adam Henrique         2014 N.J               CAN           72           197
# Adam Larsson          2014 N.J               SWE           75           208
# Adam McQuaid          2014 BOS               CAN           76           210
# Adam Pardy            2014 WPG               CAN           76           227
# Adam Payerl           2014 PIT               CAN           75           218
# Alec Martinez         2014 L.A               USA           73           209
# Aleksander Barkov     2014 FLA               FIN           75           213
# Ales Hemsky           2014 EDM, OTT          CZE           72           177
# Alex Chiasson         2014 DAL               CAN           76           208
# Alex Galchenyuk       2014 MTL               USA           73           207
# Alex Goligoski        2014 DAL               USA           71           185
# Alex Grant            2014 ANA               CAN           75           210
# Alex Khokhlachev      2014 BOS               RUS           70           181
# Alex Killorn          2014 T.B               CAN           73           196
# Alex Ovechkin         2014 WSH               RUS           75           235
# Alex Petrovic         2014 FLA               CAN           76           216
# Alex Pietrangelo      2014 STL               CAN           75           210
# Alex Tanguay          2014 COL               CAN           73           194
# Alexander Edler       2014 VAN               SWE           75           212
# Alexander Semin       2014 CAR               RUS           74           211
# Alexander Steen       2014 STL               SWE           72           211
# Alexander Sulzer      2014 BUF               DEU           73           198
# ...                                          ...          ...           ...
# Vladimir Tarasenko    2018 STL               RUS           72           225
# Vladislav Kamenev     2018 COL               RUS           74           194
# Vladislav Namestnikov 2018 NYR, T.B          RUS           71           184
# Wade Megan            2018 STL               USA           73           191
# Warren Foegele        2018 CAR               CAN           74           198
# Wayne Simmonds        2018 PHI               CAN           74           185
# Will Butcher          2018 N.J               USA           70           190
# Will O'Neill          2018 PHI               USA           73           190
# William Carrier       2018 VGK               CAN           74           212
# William Karlsson      2018 VGK               SWE           73           189
# William Nylander      2018 TOR               SWE           72           191
# Xavier Ouellet        2018 DET               FRA           73           196
# Yanni Gourde          2018 T.B               CAN           69           172
# Yannick Weber         2018 NSH               CHE           71           200
# Yohann Auvitu         2018 EDM               FRA           71           187
# Zac Dalpe             2018 CBJ               CAN           74           194
# Zac Rinaldo           2018 ARI               CAN           70           192
# Zach Aston-Reese      2018 PIT               USA           72           204
# Zach Bogosian         2018 BUF               USA           75           226
# Zach Hyman            2018 TOR               CAN           73           209
# Zach Parise           2018 MIN               USA           71           193
# Zach Redmond          2018 BUF               USA           74           212
# Zach Trotman          2018 PIT               USA           75           217
# Zach Werenski         2018 CBJ               USA           74           209
# Zach Whitecloud       2018 VGK               CAN           74           209
# Zack Kassian          2018 EDM               CAN           75           211
# Zack Mitchell         2018 MIN               CAN           73           188
# Zack Smith            2018 OTT               CAN           74           208
# Zdeno Chara           2018 BOS               SVK           81           250
# Zemgus Girgensons     2018 BUF               LVA           74           211
#
#                                      Draft_Year  Draft_Team  Draft_Round  \
# Player                Year Team
# Aaron Ness            2014 NYI           2008.0         NYI          2.0
# Aaron Palushaj        2014 CAR           2007.0         STL          2.0
# Aaron Rome            2014 DAL           2002.0         L.A          4.0
# Aaron Volpatti        2014 WSH              NaN         NaN          NaN
# Adam Almquist         2014 DET           2009.0         DET          7.0
# Adam Burish           2014 S.J           2002.0         CHI          9.0
# Adam Cracknell        2014 STL           2004.0         CGY          9.0
# Adam Hall             2014 PHI           1999.0         NSH          2.0
# Adam Henrique         2014 N.J           2008.0         N.J          3.0
# Adam Larsson          2014 N.J           2011.0         N.J          1.0
# Adam McQuaid          2014 BOS           2005.0         CBJ          2.0
# Adam Pardy            2014 WPG           2004.0         CGY          6.0
# Adam Payerl           2014 PIT              NaN         NaN          NaN
# Alec Martinez         2014 L.A           2007.0         L.A          4.0
# Aleksander Barkov     2014 FLA           2013.0         FLA          1.0
# Ales Hemsky           2014 EDM, OTT      2001.0         EDM          1.0
# Alex Chiasson         2014 DAL           2009.0         DAL          2.0
# Alex Galchenyuk       2014 MTL           2012.0         MTL          1.0
# Alex Goligoski        2014 DAL           2004.0         PIT          2.0
# Alex Grant            2014 ANA           2007.0         PIT          4.0
# Alex Khokhlachev      2014 BOS           2011.0         BOS          2.0
# Alex Killorn          2014 T.B           2007.0         T.B          3.0
# Alex Ovechkin         2014 WSH           2004.0         WSH          1.0
# Alex Petrovic         2014 FLA           2010.0         FLA          2.0
# Alex Pietrangelo      2014 STL           2008.0         STL          1.0
# Alex Tanguay          2014 COL           1998.0         COL          1.0
# Alexander Edler       2014 VAN           2004.0         VAN          3.0
# Alexander Semin       2014 CAR           2002.0         WSH          1.0
# Alexander Steen       2014 STL           2002.0         TOR          1.0
# Alexander Sulzer      2014 BUF           2003.0         NSH          3.0
# ...                                         ...         ...          ...
# Vladimir Tarasenko    2018 STL           2010.0         STL          1.0
# Vladislav Kamenev     2018 COL           2014.0         NSH          2.0
# Vladislav Namestnikov 2018 NYR, T.B      2011.0         T.B          1.0
# Wade Megan            2018 STL           2009.0         FLA          5.0
# Warren Foegele        2018 CAR           2014.0         CAR          3.0
# Wayne Simmonds        2018 PHI           2007.0         L.A          2.0
# Will Butcher          2018 N.J           2013.0         COL          5.0
# Will O'Neill          2018 PHI           2006.0         ATL          7.0
# William Carrier       2018 VGK           2013.0         STL          2.0
# William Karlsson      2018 VGK           2011.0         ANA          2.0
# William Nylander      2018 TOR           2014.0         TOR          1.0
# Xavier Ouellet        2018 DET           2011.0         DET          2.0
# Yanni Gourde          2018 T.B              NaN         NaN          NaN
# Yannick Weber         2018 NSH           2007.0         MTL          3.0
# Yohann Auvitu         2018 EDM              NaN         NaN          NaN
# Zac Dalpe             2018 CBJ           2008.0         CAR          2.0
# Zac Rinaldo           2018 ARI           2008.0         PHI          6.0
# Zach Aston-Reese      2018 PIT              NaN         NaN          NaN
# Zach Bogosian         2018 BUF           2008.0         ATL          1.0
# Zach Hyman            2018 TOR           2010.0         FLA          5.0
# Zach Parise           2018 MIN           2003.0         N.J          1.0
# Zach Redmond          2018 BUF           2008.0         ATL          7.0
# Zach Trotman          2018 PIT           2010.0         BOS          7.0
# Zach Werenski         2018 CBJ           2015.0         CBJ          1.0
# Zach Whitecloud       2018 VGK              NaN         NaN          NaN
# Zack Kassian          2018 EDM           2009.0         BUF          1.0
# Zack Mitchell         2018 MIN              NaN         NaN          NaN
# Zack Smith            2018 OTT           2008.0         OTT          3.0
# Zdeno Chara           2018 BOS           1996.0         NYI          3.0
# Zemgus Girgensons     2018 BUF           2012.0         BUF          1.0
#
#                                      Round_Pick  Overall_Draft_Position
# Player                Year Team
# Aaron Ness            2014 NYI             10.0                    40.0
# Aaron Palushaj        2014 CAR             14.0                    44.0
# Aaron Rome            2014 DAL              8.0                   104.0
# Aaron Volpatti        2014 WSH              NaN                     NaN
# Adam Almquist         2014 DET             29.0                   210.0
# Adam Burish           2014 S.J             22.0                   282.0
# Adam Cracknell        2014 STL             21.0                   279.0
# Adam Hall             2014 PHI             24.0                    52.0
# Adam Henrique         2014 N.J             21.0                    82.0
# Adam Larsson          2014 N.J              4.0                     4.0
# Adam McQuaid          2014 BOS             25.0                    55.0
# Adam Pardy            2014 WPG             10.0                   173.0
# Adam Payerl           2014 PIT              NaN                     NaN
# Alec Martinez         2014 L.A              4.0                    95.0
# Aleksander Barkov     2014 FLA              2.0                     2.0
# Ales Hemsky           2014 EDM, OTT        13.0                    13.0
# Alex Chiasson         2014 DAL              8.0                    38.0
# Alex Galchenyuk       2014 MTL              3.0                     3.0
# Alex Goligoski        2014 DAL             31.0                    61.0
# Alex Grant            2014 ANA             27.0                   118.0
# Alex Khokhlachev      2014 BOS             10.0                    40.0
# Alex Killorn          2014 T.B             16.0                    77.0
# Alex Ovechkin         2014 WSH              1.0                     1.0
# Alex Petrovic         2014 FLA              6.0                    36.0
# Alex Pietrangelo      2014 STL              4.0                     4.0
# Alex Tanguay          2014 COL             12.0                    12.0
# Alexander Edler       2014 VAN             26.0                    91.0
# Alexander Semin       2014 CAR             13.0                    13.0
# Alexander Steen       2014 STL             24.0                    24.0
# Alexander Sulzer      2014 BUF             24.0                    92.0
# ...                                         ...                     ...
# Vladimir Tarasenko    2018 STL             16.0                    16.0
# Vladislav Kamenev     2018 COL             12.0                    42.0
# Vladislav Namestnikov 2018 NYR, T.B        27.0                    27.0
# Wade Megan            2018 STL             17.0                   138.0
# Warren Foegele        2018 CAR              7.0                    67.0
# Wayne Simmonds        2018 PHI             31.0                    61.0
# Will Butcher          2018 N.J              2.0                   123.0
# Will O'Neill          2018 PHI             27.0                   210.0
# William Carrier       2018 VGK             27.0                    57.0
# William Karlsson      2018 VGK             23.0                    53.0
# William Nylander      2018 TOR              8.0                     8.0
# Xavier Ouellet        2018 DET             18.0                    48.0
# Yanni Gourde          2018 T.B              NaN                     NaN
# Yannick Weber         2018 NSH             12.0                    73.0
# Yohann Auvitu         2018 EDM              NaN                     NaN
# Zac Dalpe             2018 CBJ             15.0                    45.0
# Zac Rinaldo           2018 ARI             27.0                   178.0
# Zach Aston-Reese      2018 PIT              NaN                     NaN
# Zach Bogosian         2018 BUF              3.0                     3.0
# Zach Hyman            2018 TOR              3.0                   123.0
# Zach Parise           2018 MIN             17.0                    17.0
# Zach Redmond          2018 BUF              3.0                   184.0
# Zach Trotman          2018 PIT             30.0                   210.0
# Zach Werenski         2018 CBJ              8.0                     8.0
# Zach Whitecloud       2018 VGK              NaN                     NaN
# Zack Kassian          2018 EDM             13.0                    13.0
# Zack Mitchell         2018 MIN              NaN                     NaN
# Zack Smith            2018 OTT             18.0                    79.0
# Zdeno Chara           2018 BOS              4.0                    56.0
# Zemgus Girgensons     2018 BUF             14.0                    14.0
#
# [4444 rows x 254 columns]

# %% [markdown]
# ### Dealing with NAs
#
# Given the specialty nature of this data set there are few na values. The notable exception is Draft information, as a number of players were undrafted. After consideration, I decided to make this a number higher than possible, 1000, which would make it stand out and be important for a linear regression, where as if I make it say, 0, it would be decidedly right by 1, which is the ideal draft ranking.
#
# Draft Year I made into 1900, and team is now 'Undrafted'.
#
# As far as other missing values, Instead of writing out the reasoning for each fill here, I'll explain thusly: if the value is a count or a percentage of a count, I entered it as zero. If it's a percentage of a rate, then I filled to median. Example of each:
#
# 1) IPP is Individual Point Percentage, the percentage of goals for that player's team while that player is on the ice that the player earned a point on. For this I filled the NA to 0, becuase logically if you have no points in this category your count would be zero.
#
# 2) OffZoneStartPer is Offensive Zone Start Percentage. this is a rate, and thus, simply hasn't been calculated since the player hasn't been given the opportunity to have such a stat created.
#
# In essence the logic here is "if you have a NA due to not getting any points, you are marked zero, if you have an NA due to not being on the ice for that metric, you are returned to the mean.
#
# There is another alternative which is I found some pointless columns (power play position, etc) which I dropped wholesale.
#
# Finally, I did a lot of manual iterations of printing out the list of over the 181 columns with missing values and changing each. while I've retained the fill in code below I'm deleting the boring iteration of making a list of the columns with na, then printing that list. Instead I've saved the fill segment.

# %%
## quick glance at what has missing values
comb_player_data.isnull().sum()
# Out:
# Position                     0
# GP                           0
# TOI                          0
# Goals                        0
# Total_Assists                0
# First_Assists                0
# Second_Assists               0
# Total_Points                 0
# IPP                        332
# Shots                        0
# SHPer                      126
# iCF                          0
# iFF                          0
# iSCF                         0
# iHDCF                        0
# Rush_Attempts                0
# Rebounds_Created             0
# PIM                          0
# Total_Penalties              0
# Minor                        0
# Major                        0
# Misconduct                   0
# Penalties_Drawn              0
# Giveaways                    0
# Takeaways                    0
# Hits                         0
# Hits_Taken                   0
# Shots_Blocked                0
# Faceoffs_Won                 0
# Faceoffs_Lost                0
#                           ...
# LDCFPer                      1
# LDGF_60                      0
# LDGA_60                      0
# LDGFPer                    512
# On-Ice_SHPer                10
# On-Ice_SVPer                 3
# PDO                          1
# Off. Zone_Faceoffs_60        0
# Neu. Zone_Faceoffs_60        0
# Def. Zone_Faceoffs_60        0
# OnTFStarts_60                0
# OffZoneStartPer             16
# OffZoneFaceoffs_60           0
# NeuZoneFaceoffs_60           0
# DefZoneFaceoffs_60           0
# Off. Zone_Faceoff_Per        2
# Position_Bios                0
# Age                          0
# Date_of_Birth                0
# Birth_City                   0
# Birth_State/Province      1090
# Birth_Country                0
# Nationality                  0
# Height_(in)                  0
# Weight_(lbs)                 0
# Draft_Year                 665
# Draft_Team                 665
# Draft_Round                665
# Round_Pick                 665
# Overall_Draft_Position     665
# Length: 254, dtype: int64

# %%
## cleaning up the draft data
comb_player_data['Draft_Round'].fillna(100,inplace = True)
comb_player_data['Draft_Year'].fillna(1900,inplace = True)
comb_player_data['Round_Pick'].fillna(100,inplace = True)
comb_player_data['Overall_Draft_Position'].fillna(1000,inplace = True)
comb_player_data['Draft_Team'].fillna('Undrafted',inplace = True)

# %%
## this is the iteration to return each value
has_na = comb_player_data.isnull().sum() > 0
comb_player_data_cols = comb_player_data.columns[has_na]
comb_player_data_cols_2 = [col for col in comb_player_data.columns if col in comb_player_data_cols]
print(comb_player_data_cols_2)
# Out:
# ['IPP', 'SHPer', 'Faceoffs_Per', 'Position_PPIndC', 'GP_PPIndC', 'TOI_PPIndC', 'Goals_PPIndC', 'Total_Assists_PPIndC', 'First_Assists_PPIndC', 'Second_Assists_PPIndC', 'Total_Points_PPIndC', 'IPP_PPIndC', 'Shots_PPIndC', 'SHPer_PPIndC', 'iCF_PPIndC', 'iFF_PPIndC', 'iSCF_PPIndC', 'iHDCF_PPIndC', 'Rush_Attempts_PPIndC', 'Rebounds_Created_PPIndC', 'PIM_PPIndC', 'Total_Penalties_PPIndC', 'Minor_PPIndC', 'Major_PPIndC', 'Misconduct_PPIndC', 'Penalties_Drawn_PPIndC', 'Giveaways_PPIndC', 'Takeaways_PPIndC', 'Hits_PPIndC', 'Hits_Taken_PPIndC', 'Shots_Blocked_PPIndC', 'Faceoffs_Won_PPIndC', 'Faceoffs_Lost_PPIndC', 'Faceoffs_Per_PPIndC', 'Position_PkIndC', 'GP_PkIndC', 'TOI_PkIndC', 'Goals_PkIndC', 'Total_Assists_PkIndC', 'First_Assists_PkIndC', 'Second_Assists_PkIndC', 'Total_Points_PkIndC', 'IPP_PkIndC', 'Shots_PkIndC', 'SHPer_PkIndC', 'iCF_PkIndC', 'iFF_PkIndC', 'iSCF_PkIndC', 'iHDCF_PkIndC', 'Rush_Attempts_PkIndC', 'Rebounds_Created_PkIndC', 'PIM_PkIndC', 'Total_Penalties_PkIndC', 'Minor_PkIndC', 'Major_PkIndC', 'Misconduct_PkIndC', 'Penalties_Drawn_PkIndC', 'Giveaways_PkIndC', 'Takeaways_PkIndC', 'Hits_PkIndC', 'Hits_Taken_PkIndC', 'Shots_Blocked_PkIndC', 'Faceoffs_Won_PkIndC', 'Faceoffs_Lost_PkIndC', 'Faceoffs_Per_PkIndC', 'Position_PkIndR', 'GP_PkIndR', 'PKTOI', 'PKTOI_GP', 'PKCF_60', 'PKCA_60', 'PKCFPer', 'PKFF_60', 'PKFA_60', 'PKFFPer', 'PKSF_60', 'PKSA_60', 'PKSFPer', 'PKGF_60', 'PKGA_60', 'PKGFPer', 'PKSCF_60', 'PKSCA_60', 'PKSCFPer', 'PKHDCF_60', 'PKHDCA_60', 'PKHDCFPer', 'PKHDGF_60', 'PKHDGA_60', 'PKHDGFPer', 'PKMDCF_60', 'PKMDCA_60', 'PKMDCFPer', 'PKMDGF_60', 'PKMDGA_60', 'PKMDGFPer', 'PKLDCF_60', 'PKLDCA_60', 'PKLDCFPer', 'PKLDGF_60', 'PKLDGA_60', 'PKLDGFPer', 'PKOn-Ice_SHPer', 'PKOn-Ice_SVPer', 'PKPDO', 'PKOff.\xa0Zone_Faceoffs_60', 'PKNeu.\xa0Zone_Faceoffs_60', 'PKDef.\xa0Zone_Faceoffs_60', 'PKOnTFStarts_60', 'PKOffZoneStartPer', 'PKOffZoneFaceoffs_60', 'PKNeuZoneFaceoffs_60', 'PKDefZoneFaceoffs_60', 'PKOff.\xa0Zone_Faceoff_Per', 'Position_PPIndR', 'GP_PPIndR', 'PPTOI', 'PPTOI_GP', 'PPCF_60', 'PPCA_60', 'PPCFPer', 'PPFF_60', 'PPFA_60', 'PPFFPer', 'PPSF_60', 'PPSA_60', 'PPSFPer', 'PPGF_60', 'PPGA_60', 'PPGFPer', 'PPSCF_60', 'PPSCA_60', 'PPSCFPer', 'PPHDCF_60', 'PPHDCA_60', 'PPHDCFPer', 'PPHDGF_60', 'PPHDGA_60', 'PPHDGFPer', 'PPMDCF_60', 'PPMDCA_60', 'PPMDCFPer', 'PPMDGF_60', 'PPMDGA_60', 'PPMDGFPer', 'PPLDCF_60', 'PPLDCA_60', 'PPLDCFPer', 'PPLDGF_60', 'PPLDGA_60', 'PPLDGFPer', 'PPOn-Ice_SHPer', 'PPOn-Ice_SVPer', 'PPPDO', 'PPOff.\xa0Zone_Faceoffs_60', 'PPNeu.\xa0Zone_Faceoffs_60', 'PPDef.\xa0Zone_Faceoffs_60', 'PPOnTFStarts_60', 'PPOffZoneStartPer', 'PPOffZoneFaceoffs_60', 'PPNeuZoneFaceoffs_60', 'PPDefZoneFaceoffs_60', 'PPOff.\xa0Zone_Faceoff_Per', 'CFPer', 'FFPer', 'SFPer', 'GFPer', 'SCFPer', 'HDCFPer', 'HDGFPer', 'MDCFPer', 'MDGFPer', 'LDCFPer', 'LDGFPer', 'On-Ice_SHPer', 'On-Ice_SVPer', 'PDO', 'OffZoneStartPer', 'Off.\xa0Zone_Faceoff_Per', 'Birth_State/Province']

# %%
## these are the count values that I'm filling as zero
fill_zero = ['SHPer_PPIndC','IPP','SHPer','GP_PPIndC','TOI_PPIndC','Goals_PPIndC','Total_Assists_PPIndC','IPP_PPIndC','Shots_PPIndC','GP_PPIndC','TOI_PPIndC','IPP_PPIndC','IPP_PPIndC', 'Shots_PPIndC', 'SHPer_PPIndC', 'iSCF_PPIndC', 'iHDCF_PPIndC', 'Rush_Attempts_PPIndC', 'Rebounds_Created_PPIndC', 'PIM_PPIndC','Total_Penalties_PPIndC', 'Minor_PPIndC', 'Major_PPIndC', 'Misconduct_PPIndC', 'Penalties_Drawn_PPIndC', 'Giveaways_PPIndC', 'Takeaways_PPIndC', 'Hits_PPIndC', 'Hits_Taken_PPIndC', 'Shots_Blocked_PPIndC', 'Faceoffs_Won_PPIndC', 'Faceoffs_Lost_PPIndC','Faceoffs_Per_PPIndC','GP_PkIndC', 'TOI_PkIndC', 'Goals_PkIndC', 'Total_Assists_PkIndC', 'IPP_PkIndC', 'Shots_PkIndC', 'SHPer_PkIndC',    'iSCF_PkIndC', 'iHDCF_PkIndC', 'Rush_Attempts_PkIndC', 'Rebounds_Created_PkIndC', 'PIM_PkIndC', 'Total_Penalties_PkIndC', 'Minor_PkIndC', 'Major_PkIndC', 'Misconduct_PkIndC', 'Penalties_Drawn_PkIndC', 'Giveaways_PkIndC', 'Takeaways_PkIndC', 'Hits_PkIndC', 'Hits_Taken_PkIndC', 'Shots_Blocked_PkIndC', 'Faceoffs_Won_PkIndC', 'Faceoffs_Lost_PkIndC', 'PKTOI', 'PKTOI_GP', 'PKCF_60', 'PKCA_60', 'PKTOI', 'PKTOI_GP', 'PKCF_60', 'PKCA_60','PKFF_60', 'PKFA_60','PKSF_60', 'PKSA_60', 'PKGF_60', 'PKGA_60','PKSCF_60', 'PKSCA_60', 'PKHDCF_60', 'PKHDCA_60',  'PKHDGF_60', 'PKHDGA_60','PKLDCF_60', 'PKLDCA_60',  'PKMDCF_60', 'PKMDCA_60', 'PKMDGF_60', 'PKMDGA_60', 'PKLDGF_60', 'PKLDGA_60',  'PKPDO', 'PKOff.\xa0Zone_Faceoffs_60', 'PKNeu.\xa0Zone_Faceoffs_60', 'PKDef.\xa0Zone_Faceoffs_60', 'PKOnTFStarts_60',     'PKOffZoneFaceoffs_60', 'PKNeuZoneFaceoffs_60', 'PKDefZoneFaceoffs_60',   'PPTOI', 'PPTOI_GP', 'PPCF_60', 'PPCA_60', 'PPFF_60', 'PPFA_60',  'PPSF_60', 'PPSA_60',  'PPGF_60', 'PPGA_60', 'PPSCF_60', 'PPSCA_60','PPHDCF_60', 'PPHDCA_60',  'PPHDGF_60', 'PPHDGA_60',  'PPMDCF_60', 'PPMDCA_60','PPMDGF_60', 'PPMDGA_60',  'PPLDCF_60', 'PPLDCA_60', 'PPLDGF_60', 'PPLDGA_60', 'PPPDO', 'PPOff.\xa0Zone_Faceoffs_60', 'PPNeu.\xa0Zone_Faceoffs_60', 'PPDef.\xa0Zone_Faceoffs_60', 'PPOnTFStarts_60',  'PPOffZoneFaceoffs_60', 'PPNeuZoneFaceoffs_60', 'PPDefZoneFaceoffs_60',  'CFPer', 'FFPer', 'SFPer', 'GFPer', 'SCFPer', 'HDCFPer', 'HDGFPer', 'MDCFPer', 'MDGFPer', 'LDCFPer', 'LDGFPer', 'On-Ice_SHPer', 'On-Ice_SVPer', 'PDO', 'OffZoneStartPer', 'Off.\xa0Zone_Faceoff_Per']

for i in fill_zero:
    comb_player_data[i].fillna(0,inplace = True)

# %%
## mean values
fill_mean = ['PPLDGFPer', 'PPOn-Ice_SHPer', 'PPOn-Ice_SVPer',  'PPLDCFPer', 'PPMDGFPer','PPMDCFPer', 'PPHDGFPer','PPHDCFPer', 'PPSCFPer','PPGFPer','PPSFPer','PPFFPer','PPCFPer','PKOff.\xa0Zone_Faceoff_Per', 'PKOffZoneStartPer','PKLDGFPer', 'PKOn-Ice_SHPer', 'PKOn-Ice_SVPer','PPOffZoneStartPer','Faceoffs_Per','Faceoffs_Per_PPIndC','Faceoffs_Per_PPIndC','iCF_PPIndC',  'PKMDCFPer', 'PKMDGFPer',  'PKLDCFPer','iFF_PPIndC','iCF_PkIndC', 'iFF_PkIndC','Faceoffs_Per_PkIndC','PKCFPer','PKFFPer','PKSFPer','PKGFPer','PKSCFPer','PKHDCFPer', 'PKHDGFPer','PPOff.\xa0Zone_Faceoff_Per' ]

for i in fill_mean:
    comb_player_data[i].fillna(comb_player_data[i].mean(),inplace = True)

# %% [markdown]
# A note on some of the things I choose to drop here, that one might quibble with:
#
# 1) I dropped first and second assists, keeping only total. Some could argue that there's some value in knowing which players are creating more secondary assists, but I think its too highly cooralated with the general assista as well as the final points so I took them out.

# %%
## the drop values
comb_player_data.drop(['Position_PPIndC', 'First_Assists_PPIndC', 'Second_Assists_PPIndC', 'Total_Points_PPIndC', 'Position_PkIndC', 'First_Assists_PkIndC', 'Second_Assists_PkIndC', 'Total_Points_PkIndC', 'Position_PkIndR', 'GP_PkIndR', 'Position_PPIndR', 'GP_PPIndR', 'Birth_State/Province','Position_PPIndR', 'GP_PPIndR','Position_PkIndR', 'GP_PkIndR',  'First_Assists_PkIndC', 'Second_Assists_PkIndC', 'Total_Points_PkIndC', 'Position_PkIndC','First_Assists','Second_Assists','Total_Points','Position_PPIndC','First_Assists_PPIndC', 'Second_Assists_PPIndC', 'Total_Points_PPIndC','Position_PPIndC','Birth_State/Province'], axis=1, inplace=True)
## dropping a few more excess columns I found, just to reduce junk variables
comb_player_data.drop(['GP_PPIndC','GP_PkIndC','Position_SIndR', 'GP_SIndR','Position_Bios'], axis=1, inplace=True)

# %%
## checking that all na are gone
has_na = comb_player_data.isnull().sum() > 0
comb_player_data_cols = comb_player_data.columns[has_na]
comb_player_data_cols_3 = [col for col in comb_player_data.columns if col in comb_player_data_cols]
print(comb_player_data_cols_3)
# Out:
# []

# %% [markdown]
# ### Creating age and fantasy score variables
#
# One of the general thesis items here is that players have a growth curve, as well as a performance drop off with age. There isn't an reliable age variable from the data, so here we will create one.
#
# Secondarily we need to create a value for the fantasy performance, as that is what we are trying to predict. Note that the scoring is specific to a certain league and isn't static, but this can be easily modified by other users to match their leagues scoring.

# %%
## reset the index so we can use the year column
comb_player_data.reset_index(inplace=True)

## year imported as an int so need to convert that from 2018 into '1-1-2018'
## going to make a mini function here and then iterate row wise
def age_formula(x,y):
    return round((datetime.strptime(str(x), '%Y')-datetime.strptime(str(y), '%m/%d/%y')).days/365)

comb_player_data['Age'] = comb_player_data.apply(lambda row: age_formula(row['Year'],row['Date_of_Birth']), axis=1)

# %%
## checking that it worked
comb_player_data['Age'].loc[comb_player_data['Player'] == 'Zdeno Chara']
# Out:
# 883     37
# 1766    38
# 2664    39
# 3552    40
# 4442    41
# Name: Age, dtype: int64

# %%
## creating fantasy value, which is essentially a basic multiplication across the essential rows
## the annoying accounting item here is that since the ppg aren't counted we have to add a lot 
## of additional multipliers

comb_player_data['Fantasy Points'] = comb_player_data['Goals']*3+comb_player_data['Total_Assists']*2+comb_player_data['Shots']*0.1+comb_player_data['Hits']*0.25+comb_player_data['Shots_Blocked']*0.5+comb_player_data['Faceoffs_Won']*0.05+comb_player_data['Goals_PPIndC']*3.5+comb_player_data['Total_Assists_PPIndC']*2.25+comb_player_data['Shots_PPIndC']*0.1+comb_player_data['Hits_PPIndC']*0.25+comb_player_data['Shots_Blocked_PPIndC']*0.5+comb_player_data['Faceoffs_Won_PPIndC']*0.05+comb_player_data['Goals_PkIndC']*5+comb_player_data['Total_Assists_PkIndC']*2.25+comb_player_data['Shots_PkIndC']*0.1+comb_player_data['Hits_PkIndC']*0.25+comb_player_data['Shots_Blocked_PkIndC']*0.5+comb_player_data['Faceoffs_Won_PkIndC']*0.05
# Out:
# ['Player',
#  'Year',
#  'Team',
#  'Position',
#  'GP',
#  'TOI',
#  'Goals',
#  'Total_Assists',
#  'IPP',
#  'Shots',
#  'SHPer',
#  'iCF',
#  'iFF',
#  'iSCF',
#  'iHDCF',
#  'Rush_Attempts',
#  'Rebounds_Created',
#  'PIM',
#  'Total_Penalties',
#  'Minor',
#  'Major',
#  'Misconduct',
#  'Penalties_Drawn',
#  'Giveaways',
#  'Takeaways',
#  'Hits',
#  'Hits_Taken',
#  'Shots_Blocked',
#  'Faceoffs_Won',
#  'Faceoffs_Lost',
#  'Faceoffs_Per',
#  'TOI_PPIndC',
#  'Goals_PPIndC',
#  'Total_Assists_PPIndC',
#  'IPP_PPIndC',
#  'Shots_PPIndC',
#  'SHPer_PPIndC',
#  'iCF_PPIndC',
#  'iFF_PPIndC',
#  'iSCF_PPIndC',
#  'iHDCF_PPIndC',
#  'Rush_Attempts_PPIndC',
#  'Rebounds_Created_PPIndC',
#  'PIM_PPIndC',
#  'Total_Penalties_PPIndC',
#  'Minor_PPIndC',
#  'Major_PPIndC',
#  'Misconduct_PPIndC',
#  'Penalties_Drawn_PPIndC',
#  'Giveaways_PPIndC',
#  'Takeaways_PPIndC',
#  'Hits_PPIndC',
#  'Hits_Taken_PPIndC',
#  'Shots_Blocked_PPIndC',
#  'Faceoffs_Won_PPIndC',
#  'Faceoffs_Lost_PPIndC',
#  'Faceoffs_Per_PPIndC',
#  'TOI_PkIndC',
#  'Goals_PkIndC',
#  'Total_Assists_PkIndC',
#  'IPP_PkIndC',
#  'Shots_PkIndC',
#  'SHPer_PkIndC',
#  'iCF_PkIndC',
#  'iFF_PkIndC',
#  'iSCF_PkIndC',
#  'iHDCF_PkIndC',
#  'Rush_Attempts_PkIndC',
#  'Rebounds_Created_PkIndC',
#  'PIM_PkIndC',
#  'Total_Penalties_PkIndC',
#  'Minor_PkIndC',
#  'Major_PkIndC',
#  'Misconduct_PkIndC',
#  'Penalties_Drawn_PkIndC',
#  'Giveaways_PkIndC',
#  'Takeaways_PkIndC',
#  'Hits_PkIndC',
#  'Hits_Taken_PkIndC',
#  'Shots_Blocked_PkIndC',
#  'Faceoffs_Won_PkIndC',
#  'Faceoffs_Lost_PkIndC',
#  'Faceoffs_Per_PkIndC',
#  'PKTOI',
#  'PKTOI_GP',
#  'PKCF_60',
#  'PKCA_60',
#  'PKCFPer',
#  'PKFF_60',
#  'PKFA_60',
#  'PKFFPer',
#  'PKSF_60',
#  'PKSA_60',
#  'PKSFPer',
#  'PKGF_60',
#  'PKGA_60',
#  'PKGFPer',
#  'PKSCF_60',
#  'PKSCA_60',
#  'PKSCFPer',
#  'PKHDCF_60',
#  'PKHDCA_60',
#  'PKHDCFPer',
#  'PKHDGF_60',
#  'PKHDGA_60',
#  'PKHDGFPer',
#  'PKMDCF_60',
#  'PKMDCA_60',
#  'PKMDCFPer',
#  'PKMDGF_60',
#  'PKMDGA_60',
#  'PKMDGFPer',
#  'PKLDCF_60',
#  'PKLDCA_60',
#  'PKLDCFPer',
#  'PKLDGF_60',
#  'PKLDGA_60',
#  'PKLDGFPer',
#  'PKOn-Ice_SHPer',
#  'PKOn-Ice_SVPer',
#  'PKPDO',
#  'PKOff.\xa0Zone_Faceoffs_60',
#  'PKNeu.\xa0Zone_Faceoffs_60',
#  'PKDef.\xa0Zone_Faceoffs_60',
#  'PKOnTFStarts_60',
#  'PKOffZoneStartPer',
#  'PKOffZoneFaceoffs_60',
#  'PKNeuZoneFaceoffs_60',
#  'PKDefZoneFaceoffs_60',
#  'PKOff.\xa0Zone_Faceoff_Per',
#  'PPTOI',
#  'PPTOI_GP',
#  'PPCF_60',
#  'PPCA_60',
#  'PPCFPer',
#  'PPFF_60',
#  'PPFA_60',
#  'PPFFPer',
#  'PPSF_60',
#  'PPSA_60',
#  'PPSFPer',
#  'PPGF_60',
#  'PPGA_60',
#  'PPGFPer',
#  'PPSCF_60',
#  'PPSCA_60',
#  'PPSCFPer',
#  'PPHDCF_60',
#  'PPHDCA_60',
#  'PPHDCFPer',
#  'PPHDGF_60',
#  'PPHDGA_60',
#  'PPHDGFPer',
#  'PPMDCF_60',
#  'PPMDCA_60',
#  'PPMDCFPer',
#  'PPMDGF_60',
#  'PPMDGA_60',
#  'PPMDGFPer',
#  'PPLDCF_60',
#  'PPLDCA_60',
#  'PPLDCFPer',
#  'PPLDGF_60',
#  'PPLDGA_60',
#  'PPLDGFPer',
#  'PPOn-Ice_SHPer',
#  'PPOn-Ice_SVPer',
#  'PPPDO',
#  'PPOff.\xa0Zone_Faceoffs_60',
#  'PPNeu.\xa0Zone_Faceoffs_60',
#  'PPDef.\xa0Zone_Faceoffs_60',
#  'PPOnTFStarts_60',
#  'PPOffZoneStartPer',
#  'PPOffZoneFaceoffs_60',
#  'PPNeuZoneFaceoffs_60',
#  'PPDefZoneFaceoffs_60',
#  'PPOff.\xa0Zone_Faceoff_Per',
#  'TOI_SIndR',
#  'TOI_GP',
#  'CF_60',
#  'CA_60',
#  'CFPer',
#  'FF_60',
#  'FA_60',
#  'FFPer',
#  'SF_60',
#  'SA_60',
#  'SFPer',
#  'GF_60',
#  'GA_60',
#  'GFPer',
#  'SCF_60',
#  'SCA_60',
#  'SCFPer',
#  'HDCF_60',
#  'HDCA_60',
#  'HDCFPer',
#  'HDGF_60',
#  'HDGA_60',
#  'HDGFPer',
#  'MDCF_60',
#  'MDCA_60',
#  'MDCFPer',
#  'MDGF_60',
#  'MDGA_60',
#  'MDGFPer',
#  'LDCF_60',
#  'LDCA_60',
#  'LDCFPer',
#  'LDGF_60',
#  'LDGA_60',
#  'LDGFPer',
#  'On-Ice_SHPer',
#  'On-Ice_SVPer',
#  'PDO',
#  'Off.\xa0Zone_Faceoffs_60',
#  'Neu.\xa0Zone_Faceoffs_60',
#  'Def.\xa0Zone_Faceoffs_60',
#  'OnTFStarts_60',
#  'OffZoneStartPer',
#  'OffZoneFaceoffs_60',
#  'NeuZoneFaceoffs_60',
#  'DefZoneFaceoffs_60',
#  'Off.\xa0Zone_Faceoff_Per',
#  'Age',
#  'Date_of_Birth',
#  'Birth_City',
#  'Birth_Country',
#  'Nationality',
#  'Height_(in)',
#  'Weight_(lbs)',
#  'Draft_Year',
#  'Draft_Team',
#  'Draft_Round',
#  'Round_Pick',
#  'Overall_Draft_Position']

# %%
comb_player_data
# Out:
#                      Player  Year      Team Position  GP          TOI  Goals  \
# 0                Aaron Ness  2014       NYI        D  20   275.250000      1
# 1            Aaron Palushaj  2014       CAR        R   2    17.516667      0
# 2                Aaron Rome  2014       DAL        D  25   301.200000      0
# 3            Aaron Volpatti  2014       WSH        L  41   300.183333      2
# 4             Adam Almquist  2014       DET        D   2    31.516667      1
# 5               Adam Burish  2014       S.J        R  15   125.383333      0
# 6            Adam Cracknell  2014       STL        R  19   151.050000      0
# 7                 Adam Hall  2014       PHI        R  80   544.033333      2
# 8             Adam Henrique  2014       N.J        C  77  1056.600000     15
# 9              Adam Larsson  2014       N.J        D  26   426.583333      1
# 10             Adam McQuaid  2014       BOS        D  30   425.933333      1
# 11               Adam Pardy  2014       WPG        D  60   802.633333      0
# 12              Adam Payerl  2014       PIT        C   2    18.300000      0
# 13            Alec Martinez  2014       L.A        D  61   809.066667      8
# 14        Aleksander Barkov  2014       FLA        C  54   772.033333      5
# 15              Ales Hemsky  2014  EDM, OTT        R  75  1006.350000     11
# 16            Alex Chiasson  2014       DAL        R  79   884.716667      7
# 17          Alex Galchenyuk  2014       MTL        C  65   802.083333     10
# 18           Alex Goligoski  2014       DAL        D  81  1498.566667      3
# 19               Alex Grant  2014       ANA        D   2    24.000000      2
# 20         Alex Khokhlachev  2014       BOS        C   1    14.733333      0
# 21             Alex Killorn  2014       T.B        L  82  1206.400000     14
# 22            Alex Ovechkin  2014       WSH        L  78  1204.216667     27
# 23            Alex Petrovic  2014       FLA        D   7    81.616667      0
# 24         Alex Pietrangelo  2014       STL        D  81  1552.650000      6
# 25             Alex Tanguay  2014       COL        L  16   217.966667      3
# 26          Alexander Edler  2014       VAN        D  63  1147.200000      3
# 27          Alexander Semin  2014       CAR        R  65  1034.583333     15
# 28          Alexander Steen  2014       STL        L  68  1022.100000     24
# 29         Alexander Sulzer  2014       BUF        D  25   391.183333      0
# ...                     ...   ...       ...      ...  ..          ...    ...
# 4414     Vladimir Tarasenko  2018       STL        R  80  1242.433333     27
# 4415      Vladislav Kamenev  2018       COL        C   3    26.383333      0
# 4416  Vladislav Namestnikov  2018  NYR, T.B        C  81  1132.733333     13
# 4417             Wade Megan  2018       STL        C   1     6.600000      0
# 4418         Warren Foegele  2018       CAR        L   2    19.750000      2
# 4419         Wayne Simmonds  2018       PHI        R  75  1042.416667     12
# 4420           Will Butcher  2018       N.J        D  81  1081.850000      2
# 4421           Will O'Neill  2018       PHI        D   1     9.416667      0
# 4422        William Carrier  2018       VGK        L  37   322.050000      1
# 4423       William Karlsson  2018       VGK        C  82  1199.666667     31
# 4424       William Nylander  2018       TOR        C  82  1200.416667     14
# 4425         Xavier Ouellet  2018       DET        D  45   564.183333      0
# 4426           Yanni Gourde  2018       T.B        C  82  1084.000000     17
# 4427          Yannick Weber  2018       NSH        D  47   559.683333      2
# 4428          Yohann Auvitu  2018       EDM        D  33   431.716667      3
# 4429              Zac Dalpe  2018       CBJ        C  12    86.416667      0
# 4430            Zac Rinaldo  2018       ARI        C  53   556.883333      5
# 4431       Zach Aston-Reese  2018       PIT        C  16   160.550000      4
# 4432          Zach Bogosian  2018       BUF        D  18   310.066667      0
# 4433             Zach Hyman  2018       TOR        C  82  1191.116667     14
# 4434            Zach Parise  2018       MIN        L  42   588.166667     13
# 4435           Zach Redmond  2018       BUF        D   3    42.816667      0
# 4436           Zach Trotman  2018       PIT        D   3    35.066667      0
# 4437          Zach Werenski  2018       CBJ        D  77  1491.000000     13
# 4438        Zach Whitecloud  2018       VGK        D   1    16.700000      0
# 4439           Zack Kassian  2018       EDM        R  74   747.800000      7
# 4440          Zack Mitchell  2018       MIN        R  23   226.533333      2
# 4441             Zack Smith  2018       OTT        L  68   935.600000      5
# 4442            Zdeno Chara  2018       BOS        D  73  1374.516667      7
# 4443      Zemgus Girgensons  2018       BUF        C  71   851.216667      5
#
#       Total_Assists     IPP  Shots       ...        Birth_Country  \
# 0                 2  100.00     23       ...                  USA
# 1                 0    0.00      2       ...                  USA
# 2                 1   10.00     15       ...                  CAN
# 3                 0   50.00     18       ...                  CAN
# 4                 0   50.00      2       ...                  SWE
# 5                 0    0.00      9       ...                  USA
# 6                 2   33.33     16       ...                  CAN
# 7                 5   53.85     49       ...                  USA
# 8                11   65.00     98       ...                  CAN
# 9                 2   27.27     20       ...                  SWE
# 10                5   28.57     25       ...                  CAN
# 11                6   20.00     45       ...                  CAN
# 12                0    0.00      4       ...                  CAN
# 13                6   38.89     52       ...                  USA
# 14               13   54.55     74       ...                  FIN
# 15               18   67.44    125       ...                  CZE
# 16               15   64.71     85       ...                  CAN
# 17               11   70.00     87       ...                  USA
# 18               24   38.57     91       ...                  USA
# 19                0   66.67      2       ...                  CAN
# 20                0    0.00      2       ...                  RUS
# 21               19   57.89    149       ...                  CAN
# 22               12   88.64    247       ...                  RUS
# 23                1   14.29      4       ...                  CAN
# 24               26   40.51    122       ...                  CAN
# 25                5   57.14     19       ...                  CAN
# 26                7   47.62    135       ...                  SWE
# 27               14   60.42    158       ...                  RUS
# 28               17   73.21    144       ...                  CAN
# 29                0    0.00     18       ...                  DEU
# ...             ...     ...    ...       ...                  ...
# 4414             23   68.49    229       ...                  RUS
# 4415              0    0.00      1       ...                  RUS
# 4416             19   60.38    114       ...                  RUS
# 4417              0    0.00      1       ...                  USA
# 4418              1  100.00      6       ...                  CAN
# 4419             16   66.67    113       ...                  CAN
# 4420             19   41.18     52       ...                  USA
# 4421              0    0.00      3       ...                  USA
# 4422              2   37.50     52       ...                  CAN
# 4423             26   70.37    139       ...                  SWE
# 4424             34   64.00    146       ...                  CAN
# 4425              7   33.33     53       ...                  FRA
# 4426             32   73.13    112       ...                  CAN
# 4427              3   33.33     40       ...                  CHE
# 4428              6   34.62     66       ...                  FRA
# 4429              0    0.00     16       ...                  CAN
# 4430              2   38.89     54       ...                  CAN
# 4431              2   85.71     19       ...                  USA
# 4432              1   20.00     28       ...                  USA
# 4433             24   54.29    139       ...                  CAN
# 4434              8   70.00     92       ...                  USA
# 4435              0    0.00      7       ...                  USA
# 4436              0    0.00      3       ...                  USA
# 4437             14   36.99    171       ...                  USA
# 4438              0    0.00      0       ...                  CAN
# 4439              9   72.73     80       ...                  CAN
# 4440              2   57.14     16       ...                  CAN
# 4441             10   60.00    107       ...                  CAN
# 4442             16   31.51    130       ...                  SVK
# 4443              8   56.52    100       ...                  LVA
#
#       Nationality  Height_(in)  Weight_(lbs)  Draft_Year  Draft_Team  \
# 0             USA           70           184      2008.0         NYI
# 1             USA           72           187      2007.0         STL
# 2             CAN           73           220      2002.0         L.A
# 3             CAN           72           215      1900.0   Undrafted
# 4             SWE           71           174      2009.0         DET
# 5             USA           73           195      2002.0         CHI
# 6             CAN           74           209      2004.0         CGY
# 7             USA           74           212      1999.0         NSH
# 8             CAN           72           197      2008.0         N.J
# 9             SWE           75           208      2011.0         N.J
# 10            CAN           76           210      2005.0         CBJ
# 11            CAN           76           227      2004.0         CGY
# 12            CAN           75           218      1900.0   Undrafted
# 13            USA           73           209      2007.0         L.A
# 14            FIN           75           213      2013.0         FLA
# 15            CZE           72           177      2001.0         EDM
# 16            CAN           76           208      2009.0         DAL
# 17            USA           73           207      2012.0         MTL
# 18            USA           71           185      2004.0         PIT
# 19            CAN           75           210      2007.0         PIT
# 20            RUS           70           181      2011.0         BOS
# 21            CAN           73           196      2007.0         T.B
# 22            RUS           75           235      2004.0         WSH
# 23            CAN           76           216      2010.0         FLA
# 24            CAN           75           210      2008.0         STL
# 25            CAN           73           194      1998.0         COL
# 26            SWE           75           212      2004.0         VAN
# 27            RUS           74           211      2002.0         WSH
# 28            SWE           72           211      2002.0         TOR
# 29            DEU           73           198      2003.0         NSH
# ...           ...          ...           ...         ...         ...
# 4414          RUS           72           225      2010.0         STL
# 4415          RUS           74           194      2014.0         NSH
# 4416          RUS           71           184      2011.0         T.B
# 4417          USA           73           191      2009.0         FLA
# 4418          CAN           74           198      2014.0         CAR
# 4419          CAN           74           185      2007.0         L.A
# 4420          USA           70           190      2013.0         COL
# 4421          USA           73           190      2006.0         ATL
# 4422          CAN           74           212      2013.0         STL
# 4423          SWE           73           189      2011.0         ANA
# 4424          SWE           72           191      2014.0         TOR
# 4425          FRA           73           196      2011.0         DET
# 4426          CAN           69           172      1900.0   Undrafted
# 4427          CHE           71           200      2007.0         MTL
# 4428          FRA           71           187      1900.0   Undrafted
# 4429          CAN           74           194      2008.0         CAR
# 4430          CAN           70           192      2008.0         PHI
# 4431          USA           72           204      1900.0   Undrafted
# 4432          USA           75           226      2008.0         ATL
# 4433          CAN           73           209      2010.0         FLA
# 4434          USA           71           193      2003.0         N.J
# 4435          USA           74           212      2008.0         ATL
# 4436          USA           75           217      2010.0         BOS
# 4437          USA           74           209      2015.0         CBJ
# 4438          CAN           74           209      1900.0   Undrafted
# 4439          CAN           75           211      2009.0         BUF
# 4440          CAN           73           188      1900.0   Undrafted
# 4441          CAN           74           208      2008.0         OTT
# 4442          SVK           81           250      1996.0         NYI
# 4443          LVA           74           211      2012.0         BUF
#
#       Draft_Round  Round_Pick  Overall_Draft_Position  Fantasy Points
# 0             2.0        10.0                    40.0           25.80
# 1             2.0        14.0                    44.0            0.95
# 2             4.0         8.0                   104.0           27.50
# 3           100.0       100.0                  1000.0           32.25
# 4             7.0        29.0                   210.0            3.45
# 5             9.0        22.0                   282.0           13.10
# 6             9.0        21.0                   279.0           18.35
# 7             2.0        24.0                    52.0           89.95
# 8             3.0        21.0                    82.0          199.45
# 9             1.0         4.0                     4.0           37.75
# 10            2.0        25.0                    55.0           50.00
# 11            6.0        10.0                   173.0           63.35
# 12          100.0       100.0                  1000.0            2.90
# 13            4.0         4.0                    95.0          127.15
# 14            1.0         2.0                     2.0          104.45
# 15            1.0        13.0                    13.0          142.50
# 16            2.0         8.0                    38.0          134.85
# 17            1.0         3.0                     3.0          114.25
# 18            2.0        31.0                    61.0          209.10
# 19            4.0        27.0                   118.0            6.45
# 20            2.0        10.0                    40.0            0.85
# 21            3.0        16.0                    77.0          157.60
# 22            1.0         1.0                     1.0          325.60
# 23            2.0         6.0                    36.0           10.90
# 24            1.0         4.0                     4.0          219.65
# 25            1.0        12.0                    12.0           36.95
# 26            3.0        26.0                    91.0          168.90
# 27            1.0        13.0                    13.0          154.05
# 28            1.0        24.0                    24.0          221.40
# 29            3.0        24.0                    92.0           31.35
# ...           ...         ...                     ...             ...
# 4414          1.0        16.0                    16.0          241.80
# 4415          2.0        12.0                    42.0            1.20
# 4416          1.0        27.0                    27.0          195.75
# 4417          5.0        17.0                   138.0            0.15
# 4418          3.0         7.0                    67.0           10.35
# 4419          2.0        31.0                    61.0          202.45
# 4420          5.0         2.0                   123.0          144.55
# 4421          7.0        27.0                   210.0            0.30
# 4422          2.0        27.0                    57.0           45.45
# 4423          2.0        23.0                    53.0          286.25
# 4424          1.0         8.0                     8.0          192.50
# 4425          2.0        18.0                    48.0           50.20
# 4426        100.0       100.0                  1000.0          217.00
# 4427          3.0        12.0                    73.0           45.25
# 4428        100.0       100.0                  1000.0           45.40
# 4429          2.0        15.0                    45.0            5.65
# 4430          6.0        27.0                   178.0           83.30
# 4431        100.0       100.0                  1000.0           34.80
# 4432          1.0         3.0                     3.0           21.90
# 4433          5.0         3.0                   123.0          172.50
# 4434          1.0        17.0                    17.0          101.40
# 4435          7.0         3.0                   184.0            2.70
# 4436          7.0        30.0                   210.0            1.85
# 4437          1.0         8.0                     8.0          174.45
# 4438        100.0       100.0                  1000.0            0.50
# 4439          1.0        13.0                    13.0           91.35
# 4440        100.0       100.0                  1000.0           27.45
# 4441          3.0        18.0                    79.0          108.25
# 4442          3.0         4.0                    56.0          163.90
# 4443          1.0        14.0                    14.0          102.95
#
# [4444 rows x 237 columns]

# %% [markdown]
# ## Done!
#
# And that's a wrap folks, we have a good file, which we'll save here to a new csv and begin the next leg, actually building some models.

# %%
comb_player_data.to_csv("Combined_Player_Data.csv")

# %% [markdown]
# Thanks for reading!
